# %% [markdown]
# <div style="text-align: center;">
#
# ## A Tutorial on Score-Based Generative Model from Scratch with JaxAIStack
# ### Hai Nguyen
# ### The University of Texas at Austin
# ### Aerospace Engineering and Engineering Mechanics
# #### 2025 August 09
#
# </div>

# %% [markdown]
# #### This notebook is a mixed version of theory and implementation of a score-based genrerative model. Materials for this notebook
# - Tutorial notebook on Score-based model: [notebook1](https://colab.research.google.com/drive/1SeXMpILhkJPjXUaesvzEhc3Ke6Zl_zxJ?usp=sharing#scrollTo=LZC7wrOvxLdL), [notebook2](https://deeplearning.neuromatch.io/tutorials/W2D4_GenerativeModels/student/W2D4_Tutorial2.html)
# - The blog post on Score-based model: [Yang Song's blog](https://yang-song.net/blog/2021/score/)
# - papers:
#   - [Pascal Vincent (2011), A connection between score matching and denoising autoencoders](https://www.iro.umontreal.ca/~vincentp/Publications/smdae_techreport.pdf)
#   - [Calvin Luo (2022), Understanding Diffusion Models: A Unified Perspective](https://arxiv.org/abs/2208.11970)

# %% [markdown]
# ## What is a generative model?
#
# It is a model (function) that can generate samples similar to the data samples $x_1, x_2, \ldots, x_N \sim p(x)$ which it has been trained on. For example, a generative model trained on images of cats, $p_\text{cat}(x)$, can generate new images that look like cats. There are many types of neural network generative models (more available at this [online course](https://online.stanford.edu/courses/xcs236-deep-generative-models)), such as:
# - Variational Autoencoders (VAEs)
# - Generative Adversarial Networks (GANs)
# - Diffusion models
# - Score-based generative models
# - Energy-based models
# - Normalizing Flows
#
# At very high level, the generative model $\mathcal{M}_{\theta}$ maps a `simple` distribution (e.g., Gaussian noise, $\mathcal{N}(0,I)$) to the data distribution. Here, `simple` means can be obtained by computer-generator. For example, we want to generate an image of $128\times 128$, we first draw a random noise `$r=np.random.randn(128, 128)` and then generate an artificial image $x_\text{generated}=\mathcal{M}_{\theta}(r)$.
#
# In this tutorial, we will focus on **score-based generative models** which is the SOTA framework.

# %% [markdown]
# ## What is data distribution $p(x)$?
#
# We say "the generative model learns the data distribution $p(x)$", but what is $p(x)$?
#
# Theoretically, $p(x)$ is called the probability density function (pdf) of the data distribution, which is a function that describes the likelihood of each possible value of $x$. For example, if we have a dataset of images of cats, the pdf $p(x)$ describes the likelihood of each possible image of a cat. If we provide the image of dog or anything else, the pdf $p(x)$ will be very small (close to zero) because it is not a cat image. $p(cat)$ is large (depends on how popular of the type of cat in the cat image dataset), while $p(dog)\approx 0$ or $p(random)\approx 0$.
#
# In reality, technically, we `never` know the analytical data distribution $p(x)$, we only have samples (data) from it, say $x_1, x_2, \ldots, x_N \sim p(x)$. For example, if we have a dataset of images of cats, we just assume/called that the images of cats are sampled from a distribution $p_\text{cat}(x)$, but there is no formula for $p_\text{cat}$.
#
#
#
# <!-- ### A few intuitions from engineering perspective on the score-based generative model -->

# %% [markdown]
# ## Score-Based Generative Model
#
# There is no $p(x)$, then, how we go from **random** image to **cat** image, in other words, climbing from $p(random)\approx 0$ to a high $p(cat)$?
#
#
# ![](images/random_to_cat.png)
#
# The score-based generative model offers a rigorous framework to gradually transform a random noise image to a data sample image, such as a cat image.
#
# $$random \rightarrow x_1 \rightarrow x_2 \rightarrow ... \rightarrow x_t \rightarrow ... \rightarrow cat $$
#
# As you shall see, the key idea is to learn the **score** of the data distribution, which is the gradient of the log probability density function (pdf) of the data distribution, i.e.,
#
# $$\nabla_x \log p(x_t)$$
#
# In plain language, the score will teach us how to climb the hill of the data distribution, i.e., go from a low probability density region (e.g., random noise) to a high probability density region (e.g., cat image).
#
# ![](images/gaussian_reverse_only.gif)

# %% [markdown]
# ## Notes: score-based model vs. diffusion model
#
# In the field, [**score-based model**](https://yang-song.net/blog/2021/score/) and [**diffusion models**](https://lilianweng.github.io/posts/2021-07-11-diffusion-models/) are often used interchangeably. At first, they were developed semi-independently, so they have different formulations and notations. On the surface.
#
# * Diffusion model uses a discrete Markov chain as a forward process. The objective is derived via the Evidence Lower Bound (ELBO) of the latent model.
# * Score-based model usually uses continuous-time stochastic differential equation (SDE). The objective is derived via denoising score matching.
#
# In the end, they were found to be equivalent, as one is roughly the discretization of the other. Here we focus on the **continuous time** framework.

# %%
from ipywidgets import widgets
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from IPython.display import HTML
import numpy as np
import seaborn as sns

# @title Plotting functions
import logging
import pandas as pd
import matplotlib.lines as mlines
logging.getLogger('matplotlib.font_manager').disabled = True
plt.rcParams['axes.unicode_minus'] = False
# You may have functions that plot results that aren't
# particularly interesting. You can add these here to hide them.

def plotting_z(z):
  """This function multiplies every element in an array by a provided value

  Args:
    z (ndarray): neural activity over time, shape (T, ) where T is number of timesteps

   """

  fig, ax = plt.subplots()

  ax.plot(z)
  ax.set(
      xlabel='Time (s)',
      ylabel='Z',
      title='Neural activity over time'
      )


def kdeplot(pnts, label="", ax=None, titlestr=None, handles=[], color="", **kwargs):
  if ax is None:
    ax = plt.gca()#figh, axs = plt.subplots(1,1,figsize=[6.5, 6])
  sns.kdeplot(x=pnts[:,0], y=pnts[:,1], ax=ax, label=label, color=color, **kwargs)
  handles.append(mlines.Line2D([], [], color=color, label=label))
  if titlestr is not None:
    ax.set_title(titlestr)


def quiver_plot(pnts, vecs, *args, **kwargs):
  plt.quiver(pnts[:, 0], pnts[:,1], vecs[:, 0], vecs[:, 1], *args, **kwargs)


def gmm_pdf_contour_plot(gmm, xlim=None, ylim=None, ticks=100, logprob=False, label=None, show_labels=True, **kwargs):
    if xlim is None:
        xlim = plt.xlim()
    if ylim is None:
        ylim = plt.ylim()
    xx, yy = np.meshgrid(np.linspace(*xlim, ticks), np.linspace(*ylim, ticks))
    pdf = gmm.pdf(np.dstack((xx, yy)))
    if logprob:
        pdf = np.log(pdf)
    
    # Create contour plot
    cs = plt.contour(xx, yy, pdf, **kwargs)
    
    # Add contour labels if requested
    if show_labels:
        plt.clabel(cs, inline=True, fontsize=8, fmt='%.1f')


def visualize_diffusion_distr(x_traj_rev, leftT=0, rightT=-1, explabel=""):
  if rightT == -1:
    rightT = x_traj_rev.shape[2]-1
  figh, axs = plt.subplots(1,2,figsize=[12,6])
  sns.kdeplot(x=x_traj_rev[:,0,leftT], y=x_traj_rev[:,1,leftT], ax=axs[0])
  axs[0].set_title("Density of Gaussian Prior of $x_T$\n before reverse diffusion")
  plt.axis("equal")
  sns.kdeplot(x=x_traj_rev[:,0,rightT], y=x_traj_rev[:,1,rightT], ax=axs[1])
  axs[1].set_title(f"Density of $x_0$ samples after {rightT} step reverse diffusion")
  plt.axis("equal")
  plt.suptitle(explabel)
  return figh

# %% [markdown]
# # Section 1: Understanding Score and Diffusion (analytically)

# %% [markdown]
# ## Section 1.1:  Diffusion Process
# ### forward process
#
# In this section, we'd like to understand the forward diffusion process, and gain intuition about how diffusion turns data into "noise".
#
# In this tutorial, we will use the process also known as Variance Exploding SDE (VPSDE) in diffusion literature.
#
# \begin{equation}
# d\mathbf x=g(t)d\mathbf w
# \end{equation}
#
# $d\mathbf w$ is the differential of the Wiener process, which is like the Gaussian random noise; $g(t)$ is the diffusion coefficient at time $t$. In our code, we can discretize it as:
#
# \begin{equation}
# \mathbf{x}_{t+\Delta t} = \mathbf{x}_{t}+g(t) \sqrt{\Delta t} z_t
# \end{equation}
#
# where $z_t\sim \mathcal{N} (0,I)$ are independent and identically distributed (i.i.d.) normal random variable.
#
# Given an initial state $\mathbf{x}_0$ the conditional distribution of $\mathbf{x}_t$ is a Gaussian around $\mathbf x_0$:
#
# \begin{equation}
# p(\mathbf{x}_t\mid \mathbf{x}_0) = \mathcal N(\mathbf{x}_t;\mathbf{x}_0,\sigma_t^2 I)
# \end{equation}
#
# The key quantity to note is the $\sigma_t$ which is the integrated noise scale at time $t$. $I$ denotes the identity matrix.
#
# \begin{equation}
# \sigma_t^2=∫_0^t g^2(\tau)d\tau
# \end{equation}
#
# Marginalizing over all the initial states, the distribution of $\mathbf x_t$ is $p_t(x_t)$, i.e., convolving a Gaussian over the initial data distribution $p_0(\mathbf x_0)$ which blurs the data up.
#
# \begin{equation}
# p_t(\mathbf{x}_t) = \int_{\mathbf x_0} p_0(\mathbf x_0)\mathcal N(\mathbf{x}_t;\mathbf{x}_0,\sigma_t^2 I)
# \end{equation}

# %% [markdown]
# ### Interactive Demo 1.1: Visualizing diffusion
#
# Here, we will examine the evolution of the density of a distribution $p_t(\mathbf{x})$ undergoing forward diffusion. In this case, we let $g(t)=\lambda^{t}$.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import os

# Create images directory if it doesn't exist
os.makedirs('images', exist_ok=True)

# Parameters
lambdas = [10, 25, 100]
np.random.seed(0)
timesteps = 100
sampleN = 20
t = np.linspace(0, 1, timesteps)

# Generate random normal samples for the Wiener process (same for all lambdas)
dw = np.random.normal(0, np.sqrt(t[1] - t[0]), size=(len(t), sampleN))

# Sample initial positions from a bimodal distribution (same for all lambdas)
x0 = np.concatenate((np.random.normal(-5, 1, size=(sampleN//2)),
                    np.random.normal(5, 1, size=(sampleN - sampleN//2))), axis=-1)

# Compute the diffusion process for all lambdas
x_all = []
for Lambda in lambdas:
    x = np.cumsum((Lambda**t[:,None]) * dw, axis=0) + x0.reshape(1,sampleN)
    x_all.append(x)

# Create figure with 3 subplots
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
fig.suptitle('1D Diffusion Process Comparison', fontsize=16, fontweight='bold')

def update(frame):
    for i, (ax, Lambda, x) in enumerate(zip(axes, lambdas, x_all)):
        ax.clear()
        
        # Plot trajectories up to current frame
        if frame > 0:
            ax.plot(t[:frame+1], x[:frame+1,:sampleN//2], alpha=0.3, color="red", linewidth=0.8)
            ax.plot(t[:frame+1], x[:frame+1,sampleN//2:], alpha=0.3, color="blue", linewidth=0.8)
        
        # Add points at current step
        current_time = t[frame]
        ax.scatter([current_time] * (sampleN//2), x[frame, :sampleN//2], 
                  color='red', s=40, alpha=0.9, zorder=5, edgecolors='darkred')
        ax.scatter([current_time] * (sampleN - sampleN//2), x[frame, sampleN//2:], 
                  color='blue', s=40, alpha=0.9, zorder=5, edgecolors='darkblue')
        
        ax.set_xlabel('Time')
        ax.set_ylabel('x')
        ax.set_title(f'$\lambda$ = {Lambda}')
        ax.grid(True, alpha=0.3)
        
        # Keep consistent axis limits for comparison
        ax.set_xlim(0, 1)
        ax.set_ylim(-80, 80)

# Create the animation
print("Creating animation...")
animation = FuncAnimation(fig, update, frames=timesteps, interval=100, repeat=True, blit=False)

# Save as GIF
print("Saving GIF...")
animation.save('images/diffusion_1d_comparison.gif', writer='pillow', fps=10)
print("GIF saved successfully as 'images/diffusion_1d_comparison.gif'")
plt.close()
# Out:
# Creating animation...
# Saving GIF...
# GIF saved successfully as 'images/diffusion_1d_comparison.gif'

# %% [markdown]
# ![](images/diffusion_1d_comparison.gif)

# %%
# @title 2D diffusion process with trajectory lines
# @markdown (the animation takes a while to render)
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from IPython.display import HTML

Lambda = 26  # @param {type:"slider", min:1, max:50, step:1}
timesteps = 100
sampleN = 20
t = np.linspace(0, 1, timesteps)

# Generate random normal samples for the Wiener process
dw = np.random.normal(0, np.sqrt(t[1] - t[0]), size=(len(t), 2, sampleN))

# Sample initial positions from a bimodal distribution
x0 = np.concatenate((np.random.normal(-2, .2, size=(2, sampleN//2)),
                     np.random.normal(2, .2, size=(2, sampleN - sampleN//2))),
                    axis=-1)

# Compute the diffusion process for multiple trajectories
x = np.cumsum((Lambda**t)[:, None, None] * dw, axis=0) + x0[None, :, :]

fig, ax = plt.subplots(figsize=(8, 8))
ax.set_xlim(-25, 25)
ax.set_ylim(-25, 25)
ax.axis("equal")

# Reduce number of trajectories to display for better visibility
n_display_trajectories = min(50, sampleN//4)  # Show subset of trajectories
display_indices1 = np.random.choice(sampleN//2, n_display_trajectories//2, replace=False)
display_indices2 = np.random.choice(range(sampleN//2, sampleN), n_display_trajectories//2, replace=False)

def update(frame):
    ax.clear()
    ax.set_xlim(-25, 25)
    ax.set_ylim(-25, 25)
    ax.axis("equal")
    ax.set_title(f'2D Diffusion Process with Trajectories\nTime Step: {frame}/{timesteps-1}\nλ = {Lambda}', 
                 fontsize=14, fontweight='bold')
    ax.grid(True, alpha=0.3)
    
    # Plot trajectory lines from initial position to current position
    # For red group (first mode)
    for idx in range(sampleN):
        trajectory_x = x[:frame+1, 0, idx]
        trajectory_y = x[:frame+1, 1, idx]
        ax.plot(trajectory_x, trajectory_y, color='red', alpha=0.3, linewidth=0.8)
    
    # For blue group (second mode)  
    for idx in range(sampleN):
        trajectory_x = x[:frame+1, 0, idx]
        trajectory_y = x[:frame+1, 1, idx]
        ax.plot(trajectory_x, trajectory_y, color='blue', alpha=0.3, linewidth=0.8)
    
    # Plot current positions as larger points
    ax.scatter(x[frame, 0, :sampleN//2], x[frame, 1, :sampleN//2], 
              color="red", alpha=0.7, s=25, marker='s', 
              edgecolors='darkred', linewidth=0.8, label='Current (Mode 1)')
    ax.scatter(x[frame, 0, sampleN//2:], x[frame, 1, sampleN//2:], 
              color="blue", alpha=0.7, s=25, marker='s', 
              edgecolors='darkblue', linewidth=0.8, label='Current (Mode 2)')
    
    # Add time and diffusion information
    current_time = t[frame]
    ax.text(0.02, 0.98, f't = {current_time:.3f}\nσ²(t) = {(Lambda**(2*current_time) - 1)/(2*np.log(Lambda)):.2f}', 
            transform=ax.transAxes, fontsize=10, verticalalignment='top',
            bbox=dict(boxstyle="round,pad=0.3", facecolor='white', alpha=0.8))
    
    # Add legend
    ax.legend(loc='upper right', fontsize=9, framealpha=0.9)
    
    ax.set_xlabel('X₁', fontsize=12)
    ax.set_ylabel('X₂', fontsize=12)
    ax.set_xlim(-30, 30)
    ax.set_ylim(-30, 30)
    
# Create the animation
animation = FuncAnimation(fig, update, frames=range(timesteps), interval=100, repeat=True)

# Save as GIF
animation.save('images/diffusion_process_2d_animation.gif', writer='pillow', fps=10)

# Display the animation
plt.tight_layout()
plt.close()  # Prevents displaying the initial static plot
# HTML(animation.to_jshtml())

# %% [markdown]
# ![](images/diffusion_process_2d_animation.gif)

# %% [markdown]
# ## Section 1.2:  What is Score
#
# The big idea of diffusion model is to use the **"score" function** to reverse the diffusion process. So what is score, what's the intuition to it?
#
#
# The **Score** is the gradient of the log data distribution, so it tells us which direction to go to increase the probability of data.
#
# \begin{equation}
# \mathbf{s}(\mathbf{x})=\nabla \log p(\mathbf{x})
# \end{equation}

# %% [markdown]
# ### Example: Score for Gaussian Mixtures
#
# In this exercise, you will explore the score function of a Gaussian mixture to gain more intuition about its geometry.

# %%
# @title  Custom Gaussian Mixture class
# @markdown *Execute this cell to define the class Gaussian Mixture Model for our exercise*

from scipy.stats import multivariate_normal

class GaussianMixture:
  def __init__(self, mus, covs, weights):
    """
    mus: a list of K 1d np arrays (D,)
    covs: a list of K 2d np arrays (D, D)
    weights: a list or array of K unnormalized non-negative weights, signifying the possibility of sampling from each branch.
      They will be normalized to sum to 1. If they sum to zero, it will err.
    """
    self.n_component = len(mus)
    self.mus = mus
    self.covs = covs
    self.precs = [np.linalg.inv(cov) for cov in covs]
    self.weights = np.array(weights)
    self.norm_weights = self.weights / self.weights.sum()
    self.RVs = []
    for i in range(len(mus)):
      self.RVs.append(multivariate_normal(mus[i], covs[i]))
    self.dim = len(mus[0])

  def add_component(self, mu, cov, weight=1):
    self.mus.append(mu)
    self.covs.append(cov)
    self.precs.append(np.linalg.inv(cov))
    self.RVs.append(multivariate_normal(mu, cov))
    self.weights.append(weight)
    self.norm_weights = self.weights / self.weights.sum()
    self.n_component += 1

  def pdf_decompose(self, x):
    """
      probability density (PDF) at $x$.
    """
    component_pdf = []
    prob = None
    for weight, RV in zip(self.norm_weights, self.RVs):
        pdf = weight * RV.pdf(x)
        prob = pdf if prob is None else (prob + pdf)
        component_pdf.append(pdf)
    component_pdf = np.array(component_pdf)
    return prob, component_pdf

  def pdf(self, x):
    """
      probability density (PDF) at $x$.
    """
    prob = None
    for weight, RV in zip(self.norm_weights, self.RVs):
        pdf = weight * RV.pdf(x)
        prob = pdf if prob is None else (prob + pdf)
    # component_pdf = np.array([rv.pdf(x) for rv in self.RVs]).T
    # prob = np.dot(component_pdf, self.norm_weights)
    return prob

  def score(self, x):
    """
    Compute the score $\nabla_x \log p(x)$ for the given $x$.
    """
    component_pdf = np.array([rv.pdf(x) for rv in self.RVs]).T
    weighted_compon_pdf = component_pdf * self.norm_weights[np.newaxis, :]
    participance = weighted_compon_pdf / weighted_compon_pdf.sum(axis=1, keepdims=True)

    scores = np.zeros_like(x)
    for i in range(self.n_component):
      gradvec = - (x - self.mus[i]) @ self.precs[i]
      scores += participance[:, i:i+1] * gradvec

    return scores

  def score_decompose(self, x):
    """
    Compute the grad to each branch for the score $\nabla_x \log p(x)$ for the given $x$.
    """
    component_pdf = np.array([rv.pdf(x) for rv in self.RVs]).T
    weighted_compon_pdf = component_pdf * self.norm_weights[np.newaxis, :]
    participance = weighted_compon_pdf / weighted_compon_pdf.sum(axis=1, keepdims=True)

    gradvec_list = []
    for i in range(self.n_component):
      gradvec = - (x - self.mus[i]) @ self.precs[i]
      gradvec_list.append(gradvec)
      # scores += participance[:, i:i+1] * gradvec

    return gradvec_list, participance

  def sample(self, N):
    """ Draw N samples from Gaussian mixture
    Procedure:
      Draw N samples from each Gaussian
      Draw N indices, according to the weights.
      Choose sample between the branches according to the indices.
    """
    rand_component = np.random.choice(self.n_component, size=N, p=self.norm_weights)
    all_samples = np.array([rv.rvs(N) for rv in self.RVs])
    gmm_samps = all_samples[rand_component, np.arange(N),:]
    return gmm_samps, rand_component, all_samples

# %%
# Gaussian mixture
mu1 = np.array([0, 1.0])
Cov1 = np.array([[1.0, 0.0], [0.0, 1.0]])

mu2 = np.array([2.0, -1.0])
Cov2 = np.array([[2.0, 0.5], [0.5, 1.0]])

gmm = GaussianMixture([mu1, mu2],[Cov1, Cov2], [1.0, 1.0])

# @title Visualize log density
show_samples = True  # @param {type:"boolean"}
np.random.seed(42)
gmm_samples, _, _ = gmm.sample(5000)
plt.figure(figsize=[8, 8])
plt.scatter(gmm_samples[:, 0],
            gmm_samples[:, 1],
            s=10,
            alpha=0.4 if show_samples else 0.0)
gmm_pdf_contour_plot(gmm, cmap="Greys", levels=20, logprob=True,)
plt.title("log density of gaussian mixture $\log p(x)$")
plt.axis("image")
plt.show()

# %% [markdown]
# #### Visualize Score
#
# Recall the score function is $\nabla \log p(\mathbf{x})$, a vector field that points in the direction of increasing probability density.

# %%
# @title Visualize Score
# set_seed(2023)
gmm_samps_few, _, _ = gmm.sample(200)
scorevecs_few = gmm.score(gmm_samps_few)
gradvec_list, participance = gmm.score_decompose(gmm_samps_few)

# @title Score for Gaussian mixture
plt.figure(figsize=[8, 8])
quiver_plot(gmm_samps_few, scorevecs_few,
            color="black", scale=25, alpha=0.7, width=0.003,
            label="score of GMM")
gmm_pdf_contour_plot(gmm, cmap="Greys")
plt.title("Score vector field $\\nabla\log p(x)$ for Gaussian Mixture \n  longer arrows indicate stronger score")
plt.axis("image")
plt.legend()
plt.show()

# %% [markdown]
# #### Score for each Gaussian mode

# %%
# @title Score for each Gaussian mode
plt.figure(figsize=[8, 8])
quiver_plot(gmm_samps_few, gradvec_list[0],
            color="blue", alpha=0.4, scale=45,
            label="score of gauss mode1")
quiver_plot(gmm_samps_few, gradvec_list[1],
            color="orange", alpha=0.4, scale=45,
            label="score of gauss mode2")
gmm_pdf_contour_plot(gmm.RVs[0], cmap="Blues")
gmm_pdf_contour_plot(gmm.RVs[1], cmap="Oranges")
plt.title("Score vector field $\\nabla\log p(x)$ for individual Gaussian modes")
plt.axis("image")
plt.legend()
plt.show()

# %% [markdown]
# #### Compare Score of individual mode with that of the mixture.

# %%
plt.figure(figsize=[8, 8])
quiver_plot(gmm_samps_few, gradvec_list[0]*participance[:, 0:1],
            color="blue", alpha=0.6, scale=25,
            label="weighted score of gauss mode1")
quiver_plot(gmm_samps_few, gradvec_list[1]*participance[:, 1:2],
            color="orange", alpha=0.6, scale=25,
            label="weighted score of gauss mode2")
quiver_plot(gmm_samps_few, scorevecs_few, color="black", scale=25, alpha=0.7,
            width=0.003, label="score of GMM")
gmm_pdf_contour_plot(gmm.RVs[0], cmap="Blues")
gmm_pdf_contour_plot(gmm.RVs[1], cmap="Oranges")
plt.title("Score vector field $\\nabla\log p(x)$ of mixture")
plt.axis("image")
plt.legend()
plt.show()

# %% [markdown]
# ## What does score tell us?
#
# Direction of the score points towards the higher density part of the distribution (up-hill of the landscape)
# Magnitude of the score tell us how far are we from the mode, the farther the larger.
#
# For multi-modal distribution e.g. GMM, score is the weighted average of score of
# individual modes the weights is proportional to the density of each mode at this point
# So the score of each point is dominated by the 'closest' modes / data points.

# %% [markdown]
# ## Section 1.3:  Reverse Diffusion
#
# After getting some intuition about the score function, we are now well-equipped to reverse the diffusion process!
#
# There is [a result in stochastic process literature](https://www.sciencedirect.com/science/article/pii/0304414982900515) that if we have the forward process
#
# \begin{equation}
# d\mathbf{x} = g(t)d \mathbf{w}
# \end{equation}
#
# Then the following process (reverse SDE) will be its time reversal:
#
# \begin{equation}
# d\mathbf{x} = -g^2(t) \nabla_\mathbf{x} \log p_t(\mathbf{x}) dt + g(t) d \mathbf{w}.
# \end{equation}
#
# where time $t$ runs backward.
#
# <br>
#
# **Time Reversal**: The solution of forward SDE is a sequence of distribution $p_t(\mathbf{x})$ from $t=0\to T$. If we start the reverse SDE with the initial distribution $p_T(\mathbf{x})$, then its solution will be the same sequence of distribution $p_t(\mathbf{x})$, but only that $t=T\to 0$.
#
# **Note:** For the general form of this result, see the Bonus section at the end of this tutorial.
#
# **Implication**  This time reversal is the foundation of the Diffusion model. We can use an interesting distribution as $p_0(\mathbf x)$ connects it with noise via forward diffusion.
#
# Then we can sample the noise and convert it back to data via the reverse diffusion process.
#
# <br>
#
# <p align='center'><img src='https://github.com/NeuromatchAcademy/course-content-dl/blob/main/tutorials/W3D1_TimeSeriesAndNaturalLanguageProcessing/static/noising_process.png?raw=True'/></p>

# %%
# @markdown Helper functions: `sigma_t_square` and `diffuse_gmm`
def sigma_t_square(t, Lambda):
    """Compute the noise variance \sigma_t^2 of the conditional distribution
    for forward process with g(t)=\lambda^t

    Formula
      \sigma_t^2 = \frac{\sigma^{2\lambda} - 1}{2 \ln(\lambda)}

    Args:
      t (scalar or ndarray): time
      Lambda (scalar): Lambda

    Returns:
      sigma_t^2
    """
    return (Lambda**(2 * t) - 1) / (2 * np.log(Lambda))


def sigma_t(t, Lambda):
    """Compute the noise std \sigma_t of the conditional distribution
    for forward process with g(t)=\lambda^t

    Formula
      \sigma_t =\sqrt{ \frac{\sigma^{2\lambda} - 1}{2 \ln(\lambda)}}

    Args:
      t (scalar or ndarray): time
      Lambda (scalar): Lambda

    Returns:
      sigma_t
    """
    return np.sqrt((Lambda**(2 * t) - 1) / (2 * np.log(Lambda)))


def diffuse_gmm(gmm, t, Lambda):
  """ Teleport a Gaussian Mixture distribution to $t$ by diffusion forward process

  The distribution p_t(x) (still a Gaussian mixture)
    following the forward diffusion SDE
  """
  sigma_t_2 = sigma_t_square(t, Lambda)  # variance
  noise_cov = np.eye(gmm.dim) * sigma_t_2
  covs_dif = [cov + noise_cov for cov in gmm.covs]
  return GaussianMixture(gmm.mus, covs_dif, gmm.weights)

# to_remove solution
def reverse_diffusion_SDE_sampling_gmm(gmm, sampN=500, Lambda=5, nsteps=500):
  """ Using exact score function to simulate the reverse SDE to sample from distribution.

  gmm: Gausian Mixture model class defined above
  sampN: Number of samples to generate
  Lambda: the $\lambda$ used in the diffusion coefficient $g(t)=\lambda^t$
  nsteps: how many discrete steps do we use to
  """
  # initial distribution $N(0,sigma_T^2 I)$
  sigmaT2 = sigma_t_square(1, Lambda)
  xT = np.sqrt(sigmaT2) * np.random.randn(sampN, 2)
  x_traj_rev = np.zeros((*xT.shape, nsteps, ))
  x_traj_rev[:,:,0] = xT
  dt = 1 / nsteps
  for i in range(1, nsteps):
    # note the time fly back $t$
    t = 1 - i * dt

    # Sample the Gaussian noise $z ~ N(0, I)$
    eps_z = np.random.randn(*xT.shape)

    # Transport the gmm to that at time $t$ and
    gmm_t = diffuse_gmm(gmm, t, Lambda)

    # Compute the score at state $x_t$ and time $t$, $\nabla \log p_t(x_t)$
    score_xt = gmm_t.score(x_traj_rev[:, :, i-1])

    # Implement the one time step update equation
    x_traj_rev[:, :, i] = x_traj_rev[:, :, i-1] + eps_z * (Lambda ** t) * np.sqrt(dt) + score_xt * dt * Lambda**(2*t)
  return x_traj_rev

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation, PillowWriter
import seaborn as sns
import matplotlib.lines as mlines

def create_kde_diffusion_gif(gmm, Lambda=25, n_forward_steps=40, n_reverse_steps=80, n_samples=2000):
    """
    Create KDE GIF of GMM diffusion process with correct time ordering
    Forward: t=0 to t=1, Reverse: t=1 to t=0
    """
    
    np.random.seed(42)
    
    # Generate forward diffusion trajectory (t: 0 → 1)
    forward_times = np.linspace(0, 1, n_forward_steps)
    forward_samples = []
    
    original_samples, _, _ = gmm.sample(n_samples)
    for t in forward_times:
        if t == 0:
            forward_samples.append(original_samples)
        else:
            sigma_noise = sigma_t(t, Lambda)
            noise = np.random.randn(n_samples, 2) * sigma_noise
            noisy_samples = original_samples + noise
            forward_samples.append(noisy_samples)
    
    # Generate reverse diffusion trajectory (t: 1 → 0)
    x_traj_rev = reverse_diffusion_SDE_sampling_gmm(gmm, sampN=n_samples, Lambda=Lambda, nsteps=n_reverse_steps)
    reverse_samples = [x_traj_rev[:, :, i] for i in range(n_reverse_steps)]
    reverse_times = np.linspace(1, 0, n_reverse_steps)  # t: 1 → 0
    
    # Combine trajectories
    all_samples = forward_samples + reverse_samples
    all_times = list(forward_times) + list(reverse_times)
    
    # Plot limits
    all_data = np.vstack(all_samples)
    margin = 1.0
    xlim = [all_data[:, 0].min() - margin, all_data[:, 0].max() + margin]
    ylim = [all_data[:, 1].min() - margin, all_data[:, 1].max() + margin]
    
    fig, ax = plt.subplots(figsize=(10, 8))
    fig.patch.set_facecolor('white')
    
    def animate_frame(frame):
        ax.clear()
        ax.set_xlim(xlim)
        ax.set_ylim(ylim)
        ax.set_aspect('equal')
        
        samples = all_samples[frame]
        t = all_times[frame]
        
        if frame < len(forward_samples):
            phase = "Forward Diffusion"
            color = "red"
        else:
            phase = "Reverse Diffusion"
            color = "blue"
        
        handles = []
        kdeplot(samples, label=f"{phase} (t={t:.3f})", ax=ax, handles=handles, 
                color=color, alpha=0.7, fill=True, thresh=0.05)
        
        if frame == 0 or frame >= len(all_samples) - 5:
            try:
                gmm_pdf_contour_plot(gmm, xlim=xlim, ylim=ylim, cmap="Greys", 
                                   levels=8, alpha=0.3, show_labels=False)
            except:
                pass
        
        ax.set_title(f'{phase} Process\nTime t = {t:.3f}', fontsize=16, fontweight='bold', pad=20)
        ax.grid(True, alpha=0.3)
        ax.set_xlabel('X₁', fontsize=12)
        ax.set_ylabel('X₂', fontsize=12)
        
        if handles:
            ax.legend(handles=handles, loc='upper right')
        
        bbox_props = dict(boxstyle="round,pad=0.3", facecolor=color, alpha=0.2, edgecolor=color)
        ax.text(0.02, 0.98, f"{phase}\nt = {t:.3f}", transform=ax.transAxes, 
                fontsize=11, fontweight='bold', verticalalignment='top', bbox=bbox_props)
    
    anim = FuncAnimation(fig, animate_frame, frames=len(all_samples), 
                        interval=120, repeat=True, blit=False)
    
    plt.tight_layout()
    
    # Save as GIF
    writer = PillowWriter(fps=8)
    anim.save('images/basic_kde_diffusion.gif', writer=writer, dpi=80)
    plt.close()
    
    return anim

def create_kde_comparison_gif(gmm, Lambda=25, n_steps=60, n_samples=2000):
    """
    Create side-by-side comparison GIF: Exact GMM evolution vs Reverse diffusion
    """
    
    np.random.seed(42)
    
    # Forward evolution: show how exact GMM evolves under diffusion
    forward_times = np.linspace(0, 1, n_steps//2)
    forward_gmms = []
    forward_samples = []
    
    for t in forward_times:
        if t == 0:
            forward_gmms.append(gmm)
            samples, _, _ = gmm.sample(n_samples)
        else:
            gmm_t = diffuse_gmm(gmm, t, Lambda)
            forward_gmms.append(gmm_t)
            samples, _, _ = gmm_t.sample(n_samples)
        forward_samples.append(samples)
    
    # Reverse diffusion sampling
    x_traj_rev = reverse_diffusion_SDE_sampling_gmm(gmm, sampN=n_samples, Lambda=Lambda, nsteps=n_steps//2)
    reverse_samples = [x_traj_rev[:, :, i] for i in range(x_traj_rev.shape[2])]
    reverse_times = 1 - np.linspace(0, 1, n_steps//2)
    
    # Plot limits
    all_data = np.vstack(forward_samples + reverse_samples)
    margin = 1.0
    xlim = [all_data[:, 0].min() - margin, all_data[:, 0].max() + margin]
    ylim = [all_data[:, 1].min() - margin, all_data[:, 1].max() + margin]
    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 7))
    fig.patch.set_facecolor('white')
    
    def animate_comparison(frame):
        ax1.clear()
        ax2.clear()
        
        for ax in [ax1, ax2]:
            ax.set_xlim(xlim)
            ax.set_ylim(ylim)
            ax.set_aspect('equal')
            ax.grid(True, alpha=0.3)
        
        if frame < len(forward_samples):
            t = forward_times[frame]
            
            handles1 = []
            kdeplot(forward_samples[frame], f"Forward t={t:.3f}", ax=ax1, 
                   handles=handles1, color="red", alpha=0.7, fill=True)
            ax1.set_title(f'Forward Diffusion\nExact GMM Evolution\nt = {t:.3f}', 
                         fontweight='bold', fontsize=14)
            ax1.legend(handles=handles1)
            
            ax2.text(0.5, 0.5, 'Reverse Diffusion\n(Starting Soon...)', 
                    transform=ax2.transAxes, ha='center', va='center', 
                    fontsize=16, bbox=dict(boxstyle="round,pad=0.5", facecolor='lightblue', alpha=0.3))
            ax2.set_title('Reverse Diffusion\n(Waiting...)', fontweight='bold', fontsize=14)
            
        else:
            reverse_idx = frame - len(forward_samples)
            t = reverse_times[reverse_idx]
            
            handles1 = []
            kdeplot(forward_samples[-1], "Forward (Final)", ax=ax1, 
                   handles=handles1, color="red", alpha=0.5, fill=True)
            ax1.set_title('Forward Diffusion\n(Complete)', fontweight='bold', fontsize=14)
            ax1.legend(handles=handles1)
            
            handles2 = []
            kdeplot(reverse_samples[reverse_idx], f"Reverse t={t:.3f}", ax=ax2, 
                   handles=handles2, color="blue", alpha=0.7, fill=True)
            ax2.set_title(f'Reverse Diffusion\nNeural Score Model\nt = {t:.3f}', 
                         fontweight='bold', fontsize=14)
            ax2.legend(handles=handles2)
            
            if reverse_idx > len(reverse_samples) - 5:
                try:
                    gmm_pdf_contour_plot(gmm, xlim=xlim, ylim=ylim, cmap="Greys", 
                                       levels=6, alpha=0.3, show_labels=False)
                except:
                    pass
        
        for ax in [ax1, ax2]:
            ax.set_xlabel('X₁', fontsize=12)
            ax.set_ylabel('X₂', fontsize=12)
    
    total_frames = len(forward_samples) + len(reverse_samples)
    
    anim = FuncAnimation(fig, animate_comparison, frames=total_frames, 
                        interval=150, repeat=True, blit=False)
    
    plt.tight_layout()
    
    # Save as GIF
    writer = PillowWriter(fps=7)
    anim.save('images/comparison_kde_diffusion.gif', writer=writer, dpi=80)
    plt.close()
    
    return anim

def create_kde_trajectory_gif(x_traj_rev, step_interval=5):
    """
    Create GIF showing multiple sample trajectories with KDE evolution
    """
    
    total_steps = x_traj_rev.shape[2]
    n_samples = min(50, x_traj_rev.shape[0])
    
    np.random.seed(42)
    traj_indices = np.random.choice(x_traj_rev.shape[0], n_samples, replace=False)
    
    all_data = x_traj_rev.reshape(-1, 2)
    margin = 1.0
    xlim = [all_data[:, 0].min() - margin, all_data[:, 0].max() + margin]
    ylim = [all_data[:, 1].min() - margin, all_data[:, 1].max() + margin]
    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 7))
    fig.patch.set_facecolor('white')
    
    def animate_trajectory(frame):
        step = frame * step_interval
        if step >= total_steps:
            step = total_steps - 1
            
        t_normalized = 1 - (step / (total_steps - 1))
        
        ax1.clear()
        ax2.clear()
        
        for ax in [ax1, ax2]:
            ax.set_xlim(xlim)
            ax.set_ylim(ylim)
            ax.set_aspect('equal')
            ax.grid(True, alpha=0.3)
        
        for i, traj_idx in enumerate(traj_indices):
            trajectory = x_traj_rev[traj_idx, :, :step+1]
            ax1.plot(trajectory[0, :], trajectory[1, :], alpha=0.6, linewidth=1, color='blue')
            ax1.scatter(trajectory[0, -1], trajectory[1, -1], s=20, alpha=0.8, color='red')
        
        ax1.set_title(f'Sample Trajectories\nStep {step}/{total_steps-1}\nt = {t_normalized:.3f}', 
                     fontweight='bold', fontsize=14)
        ax1.set_xlabel('X₁', fontsize=12)
        ax1.set_ylabel('X₂', fontsize=12)
        
        handles = []
        current_samples = x_traj_rev[:, :, step]
        kdeplot(current_samples, f"Step {step}", ax=ax2, handles=handles, 
               color="blue", alpha=0.7, fill=True)
        
        ax2.set_title(f'Density Evolution\nStep {step}/{total_steps-1}\nt = {t_normalized:.3f}', 
                     fontweight='bold', fontsize=14)
        ax2.set_xlabel('X₁', fontsize=12)
        ax2.set_ylabel('X₂', fontsize=12)
        ax2.legend(handles=handles)
    
    total_frames = (total_steps - 1) // step_interval + 1
    
    anim = FuncAnimation(fig, animate_trajectory, frames=total_frames, 
                        interval=200, repeat=True, blit=False)
    
    plt.tight_layout()
    
    # Save as GIF
    writer = PillowWriter(fps=5)
    anim.save('images/trajectory_kde_diffusion.gif', writer=writer, dpi=80)
    plt.close()
    
    return anim

def create_all_kde_gifs(gmm):
    """
    Create all three KDE GIF animations
    """
    
    # Basic KDE evolution GIF
    basic_anim = create_kde_diffusion_gif(gmm, Lambda=25, n_samples=2000)
    
    # Comparison GIF
    comparison_anim = create_kde_comparison_gif(gmm, Lambda=25, n_samples=2000)
    
    # Generate trajectory data and create trajectory GIF
    x_traj_rev = reverse_diffusion_SDE_sampling_gmm(gmm, sampN=1000, Lambda=25, nsteps=100)
    trajectory_anim = create_kde_trajectory_gif(x_traj_rev, step_interval=3)
    
    return basic_anim, comparison_anim, trajectory_anim

# %%
# basic_anim, comparison_anim, trajectory_anim = create_all_kde_gifs(gmm)

# %%
## Uncomment the code below to test your function
# set_seed(42)
x_traj_rev = reverse_diffusion_SDE_sampling_gmm(gmm, sampN=5000, Lambda=25, nsteps=400)
x0_rev = x_traj_rev[:, :, -1]
gmm_samples, _, _ = gmm.sample(5000)

figh, axs = plt.subplots(1, 1, figsize=[6.5, 6])
handles = []
kdeplot(x0_rev, "Samples from Reverse Diffusion", ax=axs, handles=handles, color="blue")
kdeplot(gmm_samples, "Samples from original GMM", ax=axs, handles=handles, color="red")
# gmm_pdf_contour_plot(gmm, cmap="Reds", levels=20)  # the exact pdf contour of gmm
plt.legend(handles=handles)
figh.show()

# %% [markdown]
# # Forward proces and then reverse process
# ![](images/comparison_kde_diffusion.gif)
#
#
# # How particles move
# ![](images/trajectory_kde_diffusion.gif)

# %% [markdown]
# # Neural network score-based model

# %%
import jax
import jax.numpy as jnp
from jax import random, grad, jit, vmap
import flax.linen as nn
import optax
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tqdm.notebook import trange
from functools import partial

# Set JAX to use float32 for better performance
jax.config.update("jax_enable_x64", False)

# %%
def loss_fn_jax(params, model_apply, x, sigma_t_fun, key, eps=1e-5):
    """JAX version of the loss function for training score-based generative models.

    Args:
        params: Model parameters
        model_apply: Model apply function
        x: A mini-batch of training data
        sigma_t_fun: A function that gives the standard deviation
        key: JAX random key
        eps: A tolerance value for numerical stability
    """
    batch_size = x.shape[0]
    
    # Sample random time steps
    key, subkey = random.split(key)
    random_t = random.uniform(subkey, (batch_size,), minval=eps, maxval=1.0)
    
    # Sample noise
    key, subkey = random.split(key)
    z = random.normal(subkey, x.shape)
    
    # Get standard deviation
    std = sigma_t_fun(random_t)
    
    # Create perturbed data
    perturbed_x = x + z * std[:, None]
    
    # Predict score using the model
    score = model_apply(params, perturbed_x, random_t)
    
    # Compute loss: ||σ_t * s_θ(x + σ_t * z, t) + z||^2
    loss_per_sample = jnp.sum((score * std[:, None] + z)**2, axis=1)
    loss = jnp.mean(loss_per_sample)
    
    return loss

# %%
class GaussianFourierProjection(nn.Module):
    """Gaussian random features for encoding time steps in JAX/Flax."""
    embed_dim: int
    scale: float = 30.0
    
    def setup(self):
        # Create fixed random weights (not trainable)
        self.W = self.param('W', 
                           lambda key: random.normal(key, (self.embed_dim // 2,)) * self.scale)
    
    def __call__(self, t):
        t_proj = t[:, None] * self.W[None, :] * 2 * jnp.pi
        return jnp.concatenate([jnp.sin(t_proj), jnp.cos(t_proj)], axis=-1)

class ScoreModel_Time_JAX(nn.Module):
    """A time-dependent score-based model in JAX/Flax."""
    sigma: float
    
    def setup(self):
        self.embed = GaussianFourierProjection(embed_dim=10, scale=1.0)
        self.net = nn.Sequential([
            nn.Dense(50),
            nn.tanh,
            nn.Dense(50), 
            nn.tanh,
            nn.Dense(2)
        ])
    
    def sigma_t_fun(self, t):
        return jnp.sqrt(sigma_t_square_jax(t, self.sigma))
    
    def __call__(self, x, t):
        t_embed = self.embed(t)
        input_features = jnp.concatenate([x, t_embed], axis=1)
        pred = self.net(input_features)
        
        # Apply inductive bias: normalize by sigma_t
        pred = pred / self.sigma_t_fun(t)[:, None]
        return pred

# %%
def sigma_t_square_jax(t, Lambda):
    """JAX version of sigma_t_square function"""
    return (Lambda**(2 * t) - 1) / (2 * jnp.log(Lambda))

def sigma_t_jax(t, Lambda):
    """JAX version of sigma_t function"""
    return jnp.sqrt(sigma_t_square_jax(t, Lambda))

# %%
def sample_X_and_score_t_depend_jax(gmm, trainN=10000, sigma=5, partition=20, EPS=0.02):
    """JAX version of sampling function"""
    trainN_part = trainN // partition
    X_train_col, y_train_col, T_train_col = [], [], []
    
    for t in np.linspace(EPS, 1.0, partition):
        gmm_dif = diffuse_gmm(gmm, t, sigma)
        X_train, _, _ = gmm.sample(trainN_part)
        y_train = gmm.score(X_train)
        
        X_train_jax = jnp.array(X_train, dtype=jnp.float32)
        y_train_jax = jnp.array(y_train, dtype=jnp.float32)
        T_train_jax = jnp.full((trainN_part,), t, dtype=jnp.float32)
        
        X_train_col.append(X_train_jax)
        y_train_col.append(y_train_jax)
        T_train_col.append(T_train_jax)
    
    X_train_jax = jnp.concatenate(X_train_col, axis=0)
    y_train_jax = jnp.concatenate(y_train_col, axis=0)
    T_train_jax = jnp.concatenate(T_train_col, axis=0)
    
    return X_train_jax, y_train_jax, T_train_jax

# %%
def test_DSM_objective_jax(gmm, epochs=2000, seed=0):
    """JAX version of the DSM objective test"""
    key = random.PRNGKey(seed)
    sigma = 25.0
    
    print("Sampling 10000 (X, t, score) for training")
    X_train_samp, y_train_samp, T_train_samp = \
        sample_X_and_score_t_depend_jax(gmm, sigma=sigma, trainN=10000,
                                        partition=500, EPS=0.01)
    
    print("Sampling 2000 (X, t, score) for testing")
    X_test_samp, y_test_samp, T_test_samp = \
        sample_X_and_score_t_depend_jax(gmm, sigma=sigma, trainN=2000,
                                        partition=500, EPS=0.01)
    
    print("Define neural network score approximator")
    model = ScoreModel_Time_JAX(sigma=sigma)
    
    # Initialize model parameters
    key, init_key = random.split(key)
    dummy_x = jnp.ones((1, 2))
    dummy_t = jnp.ones((1,))
    params = model.init(init_key, dummy_x, dummy_t)
    
    # Define sigma_t function
    sigma_t_f = lambda t: jnp.sqrt(sigma_t_square_jax(t, sigma))
    
    # Setup optimizer
    optimizer = optax.adam(learning_rate=0.005)
    opt_state = optimizer.init(params)
    
    # JIT compile the loss function and update step
    @jit
    def loss_fn_compiled(params, x, key):
        return loss_fn_jax(params, model.apply, x, sigma_t_f, key, eps=0.01)
    
    @jit
    def update_step(params, opt_state, x, key):
        loss, grads = jax.value_and_grad(loss_fn_compiled)(params, x, key)
        updates, opt_state = optimizer.update(grads, opt_state)
        params = optax.apply_updates(params, updates)
        return params, opt_state, loss
    
    @jit
    def compute_mse(params, x_data, t_data, y_true):
        y_pred = model.apply(params, x_data, t_data)
        return jnp.mean(jnp.sum((y_true - y_pred)**2, axis=1))
    
    print("Minimizing the denoising score matching objective")
    stats = []
    pbar = trange(epochs)
    
    for ep in pbar:
        key, subkey = random.split(key)
        params, opt_state, loss = update_step(params, opt_state, X_train_samp, subkey)
        
        pbar.set_description(f"step {ep} DSM objective loss {loss:.3f}")
        
        if ep % 25 == 0 or ep == epochs - 1:
            # Compute MSE for train and test
            MSE_train = compute_mse(params, X_train_samp, T_train_samp, y_train_samp)
            MSE_test = compute_mse(params, X_test_samp, T_test_samp, y_test_samp)
            
            print(f"step {ep} DSM loss {loss:.3f} train score MSE {MSE_train:.3f} " +
                  f"test score MSE {MSE_test:.3f}")
            stats.append((ep, float(loss), float(MSE_train), float(MSE_test)))
    
    stats_df = pd.DataFrame(stats, columns=['ep', 'DSM_loss', 'MSE_train', 'MSE_test'])
    return model, params, stats_df

# %%
def reverse_diffusion_SDE_sampling_jax(model_or_gmm, params=None, sampN=500, Lambda=5,
                                      nsteps=200, ndim=2, exact=False, key=None):
    """JAX version of reverse diffusion sampling"""
    if key is None:
        key = random.PRNGKey(0)
    
    sigmaT2 = sigma_t_square_jax(1.0, Lambda)
    
    # Sample initial noise
    key, subkey = random.split(key)
    xT = jnp.sqrt(sigmaT2) * random.normal(subkey, (sampN, ndim))
    
    # Initialize trajectory array
    x_traj_rev = jnp.zeros((sampN, ndim, nsteps))
    x_traj_rev = x_traj_rev.at[:, :, 0].set(xT)
    
    dt = 1.0 / nsteps
    
    for i in range(1, nsteps):
        t = 1.0 - i * dt
        
        # Sample noise
        key, subkey = random.split(key)
        eps_z = random.normal(subkey, (sampN, ndim))
        
        current_x = x_traj_rev[:, :, i-1]
        
        if exact:
            # Use exact GMM score (convert to numpy for GMM operations)
            gmm_t = diffuse_gmm(model_or_gmm, t, Lambda)
            score_xt = gmm_t.score(np.array(current_x))
            score_xt = jnp.array(score_xt)
        else:
            # Use neural network
            tvec = jnp.full((sampN,), t)
            score_xt = model_or_gmm.apply(params, current_x, tvec)
        
        # Update step
        next_x = (current_x + 
                 eps_z * (Lambda ** t) * jnp.sqrt(dt) + 
                 score_xt * dt * Lambda**(2*t))
        
        x_traj_rev = x_traj_rev.at[:, :, i].set(next_x)
    
    return np.array(x_traj_rev)

# %%
# Usage example (assuming gmm and other dependencies are available):
def run_jax_example(gmm, SEED=2021):
    """Run the complete JAX example"""
    print("Training JAX model...")
    model, params, stats_df = test_DSM_objective_jax(gmm, epochs=2000, seed=SEED)
    
    # Plot the losses
    print("Plotting losses...")
    stats_df.plot(x="ep", y=['DSM_loss', 'MSE_train', 'MSE_test'])
    plt.ylabel("Loss")
    plt.xlabel("Epoch")
    plt.title("JAX Training Progress")
    plt.show()
    
    print("Sampling with reverse SDE using the trained JAX score model")
    key = random.PRNGKey(SEED)
    x_traj_rev_appr_denois = reverse_diffusion_SDE_sampling_jax(
        model, params, sampN=5000, Lambda=25, nsteps=200, ndim=2, key=key)
    
    print("Sampling with reverse SDE using the exact score of Gaussian mixture")
    key = random.PRNGKey(SEED + 1)
    x_traj_rev_exact = reverse_diffusion_SDE_sampling_jax(
        gmm, sampN=5000, Lambda=25, nsteps=200, ndim=2, exact=True, key=key)
    
    print("Sampling from original Gaussian mixture")
    X_samp, _, _ = gmm.sample(1000)
    
    print("Comparing the distributions")
    fig, ax = plt.subplots(figsize=[7, 7])
    handles = []
    
    # Plot using seaborn (assuming kdeplot is available)
    try:
        kdeplot(x_traj_rev_appr_denois[:, :, -1],
                label="Reverse diffusion (JAX NN score learned DSM)", 
                handles=handles, color="blue")
        kdeplot(x_traj_rev_exact[:, :, -1],
                label="Reverse diffusion (Exact score)", 
                handles=handles, color="orange")
        kdeplot(X_samp, label="Samples from original GMM", 
                handles=handles, color="gray")
    except:
        # Fallback to scatter plot
        plt.scatter(x_traj_rev_appr_denois[:, 0, -1], x_traj_rev_appr_denois[:, 1, -1],
                   alpha=0.5, color="blue", label="JAX NN Reverse Diffusion", s=10)
        plt.scatter(x_traj_rev_exact[:, 0, -1], x_traj_rev_exact[:, 1, -1],
                   alpha=0.5, color="orange", label="Exact Reverse Diffusion", s=10)
        plt.scatter(X_samp[:, 0], X_samp[:, 1],
                   alpha=0.5, color="gray", label="Original GMM", s=10)
    
    plt.axis("equal")
    plt.legend(handles=handles)
    plt.title("JAX Diffusion Model Results")
    plt.show()
    
    return model, params, stats_df

# Example usage:
model, params, stats_df = run_jax_example(gmm, SEED=2021)
# Out:
# Training JAX model...
# Sampling 10000 (X, t, score) for training
# Sampling 2000 (X, t, score) for testing
# Define neural network score approximator
# Minimizing the denoising score matching objective
#   0%|          | 0/2000 [00:00<?, ?it/s]
# step 0 DSM loss 2.876 train score MSE 1.595 test score MSE 1.601
# step 25 DSM loss 0.964 train score MSE 0.980 test score MSE 0.996
# step 50 DSM loss 0.903 train score MSE 0.827 test score MSE 0.836
# step 75 DSM loss 0.866 train score MSE 0.798 test score MSE 0.811
# step 100 DSM loss 0.870 train score MSE 0.781 test score MSE 0.795
# step 125 DSM loss 0.869 train score MSE 0.768 test score MSE 0.785
# step 150 DSM loss 0.850 train score MSE 0.763 test score MSE 0.780
# step 175 DSM loss 0.861 train score MSE 0.754 test score MSE 0.770
# step 200 DSM loss 0.853 train score MSE 0.747 test score MSE 0.763
# step 225 DSM loss 0.854 train score MSE 0.740 test score MSE 0.757
# step 250 DSM loss 0.847 train score MSE 0.734 test score MSE 0.749
# step 275 DSM loss 0.843 train score MSE 0.737 test score MSE 0.753
# step 300 DSM loss 0.857 train score MSE 0.733 test score MSE 0.750
# step 325 DSM loss 0.851 train score MSE 0.730 test score MSE 0.745
# step 350 DSM loss 0.840 train score MSE 0.739 test score MSE 0.755
# step 375 DSM loss 0.833 train score MSE 0.736 test score MSE 0.752
# step 400 DSM loss 0.855 train score MSE 0.730 test score MSE 0.747
# step 425 DSM loss 0.877 train score MSE 0.733 test score MSE 0.751
# step 450 DSM loss 0.855 train score MSE 0.733 test score MSE 0.751
# step 475 DSM loss 0.851 train score MSE 0.726 test score MSE 0.742
# step 500 DSM loss 0.841 train score MSE 0.734 test score MSE 0.751
# step 525 DSM loss 0.851 train score MSE 0.733 test score MSE 0.749
# step 550 DSM loss 0.834 train score MSE 0.740 test score MSE 0.757
# step 575 DSM loss 0.834 train score MSE 0.727 test score MSE 0.743
# step 600 DSM loss 0.837 train score MSE 0.731 test score MSE 0.749
# step 625 DSM loss 0.876 train score MSE 0.725 test score MSE 0.741
# step 650 DSM loss 0.851 train score MSE 0.732 test score MSE 0.750
# step 675 DSM loss 0.843 train score MSE 0.728 test score MSE 0.744
# step 700 DSM loss 0.838 train score MSE 0.719 test score MSE 0.735
# step 725 DSM loss 0.847 train score MSE 0.735 test score MSE 0.752
# step 750 DSM loss 0.842 train score MSE 0.724 test score MSE 0.740
# step 775 DSM loss 0.838 train score MSE 0.720 test score MSE 0.737
# step 800 DSM loss 0.839 train score MSE 0.731 test score MSE 0.748
# step 825 DSM loss 0.850 train score MSE 0.726 test score MSE 0.743
# step 850 DSM loss 0.825 train score MSE 0.732 test score MSE 0.748
# step 875 DSM loss 0.824 train score MSE 0.718 test score MSE 0.735
# step 900 DSM loss 0.833 train score MSE 0.739 test score MSE 0.758
# step 925 DSM loss 0.839 train score MSE 0.741 test score MSE 0.759
# step 950 DSM loss 0.825 train score MSE 0.723 test score MSE 0.740
# step 975 DSM loss 0.867 train score MSE 0.730 test score MSE 0.747
# step 1000 DSM loss 0.862 train score MSE 0.725 test score MSE 0.741
# step 1025 DSM loss 0.820 train score MSE 0.719 test score MSE 0.734
# step 1050 DSM loss 0.835 train score MSE 0.733 test score MSE 0.748
# step 1075 DSM loss 0.831 train score MSE 0.727 test score MSE 0.744
# step 1100 DSM loss 0.829 train score MSE 0.726 test score MSE 0.742
# step 1125 DSM loss 0.863 train score MSE 0.720 test score MSE 0.736
# step 1150 DSM loss 0.849 train score MSE 0.725 test score MSE 0.741
# step 1175 DSM loss 0.819 train score MSE 0.726 test score MSE 0.741
# step 1200 DSM loss 0.842 train score MSE 0.722 test score MSE 0.739
# step 1225 DSM loss 0.866 train score MSE 0.734 test score MSE 0.753
# step 1250 DSM loss 0.830 train score MSE 0.721 test score MSE 0.737
# step 1275 DSM loss 0.829 train score MSE 0.723 test score MSE 0.739
# step 1300 DSM loss 0.855 train score MSE 0.725 test score MSE 0.741
# step 1325 DSM loss 0.841 train score MSE 0.725 test score MSE 0.742
# step 1350 DSM loss 0.848 train score MSE 0.727 test score MSE 0.743
# step 1375 DSM loss 0.850 train score MSE 0.724 test score MSE 0.741
# step 1400 DSM loss 0.844 train score MSE 0.725 test score MSE 0.741
# step 1425 DSM loss 0.842 train score MSE 0.726 test score MSE 0.743
# step 1450 DSM loss 0.840 train score MSE 0.726 test score MSE 0.742
# step 1475 DSM loss 0.856 train score MSE 0.727 test score MSE 0.744
# step 1500 DSM loss 0.841 train score MSE 0.735 test score MSE 0.752
# step 1525 DSM loss 0.831 train score MSE 0.724 test score MSE 0.740
# step 1550 DSM loss 0.845 train score MSE 0.731 test score MSE 0.749
# step 1575 DSM loss 0.836 train score MSE 0.725 test score MSE 0.740
# step 1600 DSM loss 0.831 train score MSE 0.726 test score MSE 0.743
# step 1625 DSM loss 0.826 train score MSE 0.721 test score MSE 0.738
# step 1650 DSM loss 0.856 train score MSE 0.727 test score MSE 0.744
# step 1675 DSM loss 0.841 train score MSE 0.723 test score MSE 0.740
# step 1700 DSM loss 0.839 train score MSE 0.731 test score MSE 0.748
# step 1725 DSM loss 0.823 train score MSE 0.724 test score MSE 0.739
# step 1750 DSM loss 0.830 train score MSE 0.720 test score MSE 0.736
# step 1775 DSM loss 0.825 train score MSE 0.720 test score MSE 0.736
# step 1800 DSM loss 0.812 train score MSE 0.718 test score MSE 0.736
# step 1825 DSM loss 0.835 train score MSE 0.726 test score MSE 0.743
# step 1850 DSM loss 0.853 train score MSE 0.723 test score MSE 0.739
# step 1875 DSM loss 0.835 train score MSE 0.719 test score MSE 0.736
# step 1900 DSM loss 0.817 train score MSE 0.718 test score MSE 0.735
# step 1925 DSM loss 0.840 train score MSE 0.725 test score MSE 0.741
# step 1950 DSM loss 0.840 train score MSE 0.727 test score MSE 0.745
# step 1975 DSM loss 0.837 train score MSE 0.717 test score MSE 0.733
# step 1999 DSM loss 0.842 train score MSE 0.719 test score MSE 0.735
# Plotting losses...
# Sampling with reverse SDE using the trained JAX score model
# Sampling with reverse SDE using the exact score of Gaussian mixture
# Sampling from original Gaussian mixture
# Comparing the distributions

# %%
import jax
import jax.numpy as jnp
from jax import random
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation, PillowWriter
import seaborn as sns
import matplotlib.lines as mlines

def create_neural_network_diffusion_gif(gmm, model, params, Lambda=25, n_forward_steps=40, n_reverse_steps=80, n_samples=2000):
    """
    Create KDE GIF using trained neural network score model
    Forward: t=0 to t=1, Reverse: t=1 to t=0 (using neural network)
    """
    
    np.random.seed(42)
    
    # Generate forward diffusion trajectory (t: 0 → 1) - same as before
    forward_times = np.linspace(0, 1, n_forward_steps)
    forward_samples = []
    
    original_samples, _, _ = gmm.sample(n_samples)
    for t in forward_times:
        if t == 0:
            forward_samples.append(original_samples)
        else:
            sigma_noise = sigma_t(t, Lambda)
            noise = np.random.randn(n_samples, 2) * sigma_noise
            noisy_samples = original_samples + noise
            forward_samples.append(noisy_samples)
    
    # Generate reverse diffusion trajectory using NEURAL NETWORK (t: 1 → 0)
    x_traj_rev = reverse_diffusion_SDE_sampling_jax(
        model, params, sampN=n_samples, Lambda=Lambda, nsteps=n_reverse_steps, 
        ndim=2, exact=False, key=random.PRNGKey(42))
    
    reverse_samples = [x_traj_rev[:, :, i] for i in range(n_reverse_steps)]
    reverse_times = np.linspace(1, 0, n_reverse_steps)  # t: 1 → 0
    
    # Combine trajectories
    all_samples = forward_samples + reverse_samples
    all_times = list(forward_times) + list(reverse_times)
    
    # Plot limits
    all_data = np.vstack(all_samples)
    margin = 1.0
    xlim = [all_data[:, 0].min() - margin, all_data[:, 0].max() + margin]
    ylim = [all_data[:, 1].min() - margin, all_data[:, 1].max() + margin]
    
    fig, ax = plt.subplots(figsize=(10, 8))
    fig.patch.set_facecolor('white')
    
    def animate_frame(frame):
        ax.clear()
        ax.set_xlim(xlim)
        ax.set_ylim(ylim)
        ax.set_aspect('equal')
        
        samples = all_samples[frame]
        t = all_times[frame]
        
        if frame < len(forward_samples):
            phase = "Forward Diffusion"
            color = "red"
            subtitle = "Adding Noise"
        else:
            phase = "Reverse Diffusion"
            color = "blue"
            subtitle = "Neural Network Score"
        
        handles = []
        kdeplot(samples, label=f"{phase} (t={t:.3f})", ax=ax, handles=handles, 
                color=color, alpha=0.7, fill=True, thresh=0.05)
        
        # Show original GMM contour at key frames
        if frame == 0 or frame >= len(all_samples) - 5:
            try:
                gmm_pdf_contour_plot(gmm, xlim=xlim, ylim=ylim, cmap="Greys", 
                                   levels=8, alpha=0.3, show_labels=False)
            except:
                pass
        
        ax.set_title(f'{phase} Process\n{subtitle}\nTime t = {t:.3f}', 
                     fontsize=16, fontweight='bold', pad=20)
        ax.grid(True, alpha=0.3)
        ax.set_xlabel('X₁', fontsize=12)
        ax.set_ylabel('X₂', fontsize=12)
        
        if handles:
            ax.legend(handles=handles, loc='upper right')
        
        bbox_props = dict(boxstyle="round,pad=0.3", facecolor=color, alpha=0.2, edgecolor=color)
        ax.text(0.02, 0.98, f"{phase}\n{subtitle}\nt = {t:.3f}", transform=ax.transAxes, 
                fontsize=11, fontweight='bold', verticalalignment='top', bbox=bbox_props)
    
    anim = FuncAnimation(fig, animate_frame, frames=len(all_samples), 
                        interval=120, repeat=True, blit=False)
    
    plt.tight_layout()
    
    # Save as GIF
    writer = PillowWriter(fps=8)
    anim.save('images/neural_network_diffusion.gif', writer=writer, dpi=80)
    plt.close()
    
    return anim

def create_exact_vs_neural_comparison_gif(gmm, model, params, Lambda=25, n_steps=60, n_samples=2000):
    """
    Create side-by-side comparison: Exact score vs Neural network score reverse diffusion
    """
    
    np.random.seed(42)
    
    # Generate both reverse diffusions starting from same noise
    key = random.PRNGKey(42)
    
    # Exact score reverse diffusion
    x_traj_exact = reverse_diffusion_SDE_sampling_jax(
        gmm, sampN=n_samples, Lambda=Lambda, nsteps=n_steps, 
        ndim=2, exact=True, key=key)
    
    # Neural network score reverse diffusion
    key = random.PRNGKey(42)  # Same seed for fair comparison
    x_traj_neural = reverse_diffusion_SDE_sampling_jax(
        model, params, sampN=n_samples, Lambda=Lambda, nsteps=n_steps, 
        ndim=2, exact=False, key=key)
    
    exact_samples = [x_traj_exact[:, :, i] for i in range(x_traj_exact.shape[2])]
    neural_samples = [x_traj_neural[:, :, i] for i in range(x_traj_neural.shape[2])]
    reverse_times = np.linspace(1, 0, n_steps)
    
    # Plot limits
    all_data = np.vstack(exact_samples + neural_samples)
    margin = 1.0
    xlim = [all_data[:, 0].min() - margin, all_data[:, 0].max() + margin]
    ylim = [all_data[:, 1].min() - margin, all_data[:, 1].max() + margin]
    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 7))
    fig.patch.set_facecolor('white')
    
    def animate_comparison(frame):
        ax1.clear()
        ax2.clear()
        
        for ax in [ax1, ax2]:
            ax.set_xlim(xlim)
            ax.set_ylim(ylim)
            ax.set_aspect('equal')
            ax.grid(True, alpha=0.3)
        
        t = reverse_times[frame]
        
        # Left: Exact score
        handles1 = []
        kdeplot(exact_samples[frame], f"Exact t={t:.3f}", ax=ax1, 
               handles=handles1, color="orange", alpha=0.7, fill=True)
        ax1.set_title(f'Exact Score Function\nAnalytical GMM\nt = {t:.3f}', 
                     fontweight='bold', fontsize=14)
        ax1.legend(handles=handles1)
        
        # Right: Neural network score
        handles2 = []
        kdeplot(neural_samples[frame], f"Neural t={t:.3f}", ax=ax2, 
               handles=handles2, color="blue", alpha=0.7, fill=True)
        ax2.set_title(f'Neural Network Score\nLearned from Data\nt = {t:.3f}', 
                     fontweight='bold', fontsize=14)
        ax2.legend(handles=handles2)
        
        # Add original GMM contour near the end
        if frame > len(exact_samples) - 10:
            for ax in [ax1, ax2]:
                try:
                    gmm_pdf_contour_plot(gmm, xlim=xlim, ylim=ylim, cmap="Greys", 
                                       levels=6, alpha=0.3, show_labels=False)
                except:
                    pass
        
        for ax in [ax1, ax2]:
            ax.set_xlabel('X₁', fontsize=12)
            ax.set_ylabel('X₂', fontsize=12)
    
    anim = FuncAnimation(fig, animate_comparison, frames=len(exact_samples), 
                        interval=150, repeat=True, blit=False)
    
    plt.tight_layout()
    
    # Save as GIF
    writer = PillowWriter(fps=7)
    anim.save('images/exact_vs_neural_comparison.gif', writer=writer, dpi=80)
    plt.close()
    
    return anim

def create_three_way_comparison_gif(gmm, model, params, Lambda=25, n_steps=50, n_samples=1500):
    """
    Create three-way comparison: Original GMM vs Exact reverse vs Neural reverse
    """
    
    np.random.seed(42)
    
    # Original GMM samples
    original_samples, _, _ = gmm.sample(n_samples)
    
    # Generate both reverse diffusions
    key = random.PRNGKey(42)
    x_traj_exact = reverse_diffusion_SDE_sampling_jax(
        gmm, sampN=n_samples, Lambda=Lambda, nsteps=n_steps, 
        ndim=2, exact=True, key=key)
    
    key = random.PRNGKey(42)
    x_traj_neural = reverse_diffusion_SDE_sampling_jax(
        model, params, sampN=n_samples, Lambda=Lambda, nsteps=n_steps, 
        ndim=2, exact=False, key=key)
    
    exact_samples = [x_traj_exact[:, :, i] for i in range(x_traj_exact.shape[2])]
    neural_samples = [x_traj_neural[:, :, i] for i in range(x_traj_neural.shape[2])]
    reverse_times = np.linspace(1, 0, n_steps)
    
    # Plot limits
    all_data = np.vstack([original_samples] + exact_samples + neural_samples)
    margin = 1.0
    xlim = [all_data[:, 0].min() - margin, all_data[:, 0].max() + margin]
    ylim = [all_data[:, 1].min() - margin, all_data[:, 1].max() + margin]
    
    fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 6))
    fig.patch.set_facecolor('white')
    
    def animate_three_way(frame):
        for ax in [ax1, ax2, ax3]:
            ax.clear()
            ax.set_xlim(xlim)
            ax.set_ylim(ylim)
            ax.set_aspect('equal')
            ax.grid(True, alpha=0.3)
        
        t = reverse_times[frame]
        
        # Left: Original GMM (static)
        handles1 = []
        kdeplot(original_samples, "Original GMM", ax=ax1, 
               handles=handles1, color="gray", alpha=0.7, fill=True)
        try:
            gmm_pdf_contour_plot(gmm, xlim=xlim, ylim=ylim, cmap="Greys", 
                               levels=6, alpha=0.5, show_labels=False)
        except:
            pass
        ax1.set_title('Original GMM\n(Ground Truth)', fontweight='bold', fontsize=14)
        ax1.legend(handles=handles1)
        
        # Middle: Exact score
        handles2 = []
        kdeplot(exact_samples[frame], f"Exact t={t:.3f}", ax=ax2, 
               handles=handles2, color="orange", alpha=0.7, fill=True)
        ax2.set_title(f'Exact Score\nAnalytical\nt = {t:.3f}', 
                     fontweight='bold', fontsize=14)
        ax2.legend(handles=handles2)
        
        # Right: Neural network score
        handles3 = []
        kdeplot(neural_samples[frame], f"Neural t={t:.3f}", ax=ax3, 
               handles=handles3, color="blue", alpha=0.7, fill=True)
        ax3.set_title(f'Neural Score\nLearned Model\nt = {t:.3f}', 
                     fontweight='bold', fontsize=14)
        ax3.legend(handles=handles3)
        
        # Add contours near the end for comparison
        if frame > len(exact_samples) - 10:
            for ax in [ax2, ax3]:
                try:
                    gmm_pdf_contour_plot(gmm, xlim=xlim, ylim=ylim, cmap="Greys", 
                                       levels=6, alpha=0.3, show_labels=False)
                except:
                    pass
        
        for ax in [ax1, ax2, ax3]:
            ax.set_xlabel('X₁', fontsize=12)
            ax.set_ylabel('X₂', fontsize=12)
    
    anim = FuncAnimation(fig, animate_three_way, frames=len(exact_samples), 
                        interval=150, repeat=True, blit=False)
    
    plt.tight_layout()
    
    # Save as GIF
    writer = PillowWriter(fps=7)
    anim.save('images/three_way_comparison.gif', writer=writer, dpi=80)
    plt.close()
    
    return anim

def create_neural_trajectory_gif(model, params, Lambda=25, n_samples=1000, nsteps=100, step_interval=3):
    """
    Create trajectory GIF using neural network score model
    """
    
    np.random.seed(42)
    
    # Generate neural network reverse diffusion trajectory
    x_traj_rev = reverse_diffusion_SDE_sampling_jax(
        model, params, sampN=n_samples, Lambda=Lambda, nsteps=nsteps, 
        ndim=2, exact=False, key=random.PRNGKey(42))
    
    total_steps = x_traj_rev.shape[2]
    n_display_samples = min(50, x_traj_rev.shape[0])
    
    traj_indices = np.random.choice(x_traj_rev.shape[0], n_display_samples, replace=False)
    
    all_data = x_traj_rev.reshape(-1, 2)
    margin = 1.0
    xlim = [all_data[:, 0].min() - margin, all_data[:, 0].max() + margin]
    ylim = [all_data[:, 1].min() - margin, all_data[:, 1].max() + margin]
    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 7))
    fig.patch.set_facecolor('white')
    
    def animate_trajectory(frame):
        step = frame * step_interval
        if step >= total_steps:
            step = total_steps - 1
            
        t_normalized = 1 - (step / (total_steps - 1))
        
        ax1.clear()
        ax2.clear()
        
        for ax in [ax1, ax2]:
            ax.set_xlim(xlim)
            ax.set_ylim(ylim)
            ax.set_aspect('equal')
            ax.grid(True, alpha=0.3)
        
        # Left: Trajectories
        for i, traj_idx in enumerate(traj_indices):
            trajectory = x_traj_rev[traj_idx, :, :step+1]
            ax1.plot(trajectory[0, :], trajectory[1, :], alpha=0.6, linewidth=1, color='blue')
            ax1.scatter(trajectory[0, -1], trajectory[1, -1], s=20, alpha=0.8, color='red')
        
        ax1.set_title(f'Neural Network Trajectories\nStep {step}/{total_steps-1}\nt = {t_normalized:.3f}', 
                     fontweight='bold', fontsize=14)
        ax1.set_xlabel('X₁', fontsize=12)
        ax1.set_ylabel('X₂', fontsize=12)
        
        # Right: KDE
        handles = []
        current_samples = x_traj_rev[:, :, step]
        kdeplot(current_samples, f"Neural Step {step}", ax=ax2, handles=handles, 
               color="blue", alpha=0.7, fill=True)
        
        ax2.set_title(f'Neural Network Density\nStep {step}/{total_steps-1}\nt = {t_normalized:.3f}', 
                     fontweight='bold', fontsize=14)
        ax2.set_xlabel('X₁', fontsize=12)
        ax2.set_ylabel('X₂', fontsize=12)
        ax2.legend(handles=handles)
    
    total_frames = (total_steps - 1) // step_interval + 1
    
    anim = FuncAnimation(fig, animate_trajectory, frames=total_frames, 
                        interval=200, repeat=True, blit=False)
    
    plt.tight_layout()
    
    # Save as GIF
    writer = PillowWriter(fps=5)
    anim.save('images/neural_trajectory_diffusion.gif', writer=writer, dpi=80)
    plt.close()
    
    return anim

def create_all_neural_network_gifs(gmm, model, params):
    """
    Create all neural network diffusion GIF animations
    """
    
    # 1. Basic neural network diffusion (forward + reverse with NN)
    neural_basic_anim = create_neural_network_diffusion_gif(gmm, model, params, Lambda=25, n_samples=2000)
    
    # 2. Exact vs Neural comparison
    comparison_anim = create_exact_vs_neural_comparison_gif(gmm, model, params, Lambda=25, n_samples=2000)
    
    # 3. Three-way comparison
    three_way_anim = create_three_way_comparison_gif(gmm, model, params, Lambda=25, n_samples=1500)
    
    # 4. Neural network trajectory
    trajectory_anim = create_neural_trajectory_gif(model, params, Lambda=25, n_samples=1000)
    
    return neural_basic_anim, comparison_anim, three_way_anim, trajectory_anim

# %%
# # Usage after training:
# neural_basic, exact_vs_neural, three_way, neural_traj = create_all_neural_network_gifs(gmm, model, params)

# %% [markdown]
# # Reverse process by exact score and neural network score-based model
#
# ![](images/exact_vs_neural_comparison.gif)
#
#
# # How particles move (with neural network score-based model)
# ![](images/neural_trajectory_diffusion.gif)

# %% [markdown]
# ---
# # Summary
#
# Bravo, we have come a long way today! We learned about:
#
# * The forward and reverse diffusion processes connect the data and noise distributions.
# * Sampling involves transforming noise into data through the reverse diffusion process.
# * Score function is the gradient to the data distribution, enabling the diffusion process's time reversal.
# * By learning to denoise, we can learn the score function of data by a function approximator, e.g., neural network.

# %% [markdown]
# The math that empowers the diffusion models is the reversibility of this stochastic process. Here is the general result that, given a forward diffusion process,
#
# \begin{equation}
# d\mathbf{x} = \mathbf{f}(\mathbf{x}, t)dt + g(t)d \mathbf{w}
# \end{equation}
#
# There exists a reverse time stochastic process (reverse SDE)
#
# \begin{equation}
# d\mathbf{x} =  \bigg[\mathbf{f}(\mathbf{x}, t) - g^2(t) \nabla_\mathbf{x} \log p_t(\mathbf{x}) \bigg]dt + g(t) d \mathbf{w}.
# \end{equation}
#
# and a probability flow Ordinary Differential Equation (ODE)
#
# \begin{equation}
# d\mathbf{x} = \bigg[\mathbf{f}(\mathbf{x}, t) - \frac{1}{2}g^2(t) \nabla_\mathbf{x} \log p_t(\mathbf{x})\bigg] dt.
# \end{equation}
#
# such that solving the reverse SDE or the probability flow ODE amounts to the time reversal of the solution to the forward SDE.
#
# By this math, simulating both the ODE and the SDE can sample from diffusion models.

# %% [markdown]
# # Bonus: The Math behind Score Matching Objective
#
# How to fit the score based on the samples, when we have no access to the exact scores?
#
# This objective is called denoising score matching. Mathematically, it utilized this [equivalence relationship](https://animadversio.github.io/academic_notes/note-on-equiv-score-matching-objective) of the following objectives.
#
# $$\begin{align}
# J_{DSM}(\theta) &=\mathbb{E}_{\tilde{x},x\sim p_t(\tilde{x},x)} \|s_\theta(\tilde{x})-\nabla_{\tilde{x}}\log p_t(\tilde{x}\mid x)\|^2\\
# J_{ESM}(\theta) &=\mathbb{E}_{\tilde{x}\sim p_t(\tilde{x})} \|s_\theta(\tilde{x})-\nabla_{\tilde{x}}\log p_t(\tilde{x})\|^2
# \end{align}$$
#
# In practice, it's to sample $x$ from data distribution, add noise with $\sigma$ and denoise it. Since we have at time $t$, $p_t(\tilde{x}\mid x)= \mathcal{N}(\tilde{x};x,\sigma^2_t I)$, then $\tilde{x}=x+\sigma_t z,z\sim \mathcal{N}(0,I)$. Then
#
# $$\nabla_{\tilde{x}}\log p_t(\tilde{x}|x)=-\frac{1}{\sigma_t^2}(x+\sigma_t z -x)=-\frac{1}{\sigma_t}z$$
#
# The objective simplifies into
#
# $$\mathbb{E}_{x\sim p_0(x)}\mathbb{E}_{z\sim \mathcal{N}(0,I)} \|s_\theta(x+\sigma_t z)+\frac{1}{\sigma_t}z\|^2$$
#
# Finally, in the time dependent score model $s(x,t)$, to learn this for any time $t\in [\epsilon,1]$, we integrate over all $t$ with a certain weighting function $\gamma_t$ to emphasize certain part.
#
# $$\int_\epsilon^1dt \gamma_t\mathbb{E}_{x\sim p_0(x)}\mathbb{E}_{z\sim \mathcal{N}(0,I)} \|s_\theta(x+\sigma_t z, t)+\frac{1}{\sigma_t}z\|^2$$
#
# (the $\epsilon$ is set to ensure numerical stability, as $t\to 0,\sigma_t\to 0$)
#
# Now all the expectations could be easily evaluated by sampling.
#
# A commonly used weighting is the following:
#
# $$\int_\epsilon^1dt \mathbb{E}_{x\sim p_0(x)}\mathbb{E}_{z\sim \mathcal{N}(0,I)} \|\sigma_t s_\theta(x+\sigma_t z, t)+z\|^2$$
#
# ---
#
# **Reference**
#
# * [Pascal Vincent (2011), A connection between score matching and denoising autoencoders](https://www.iro.umontreal.ca/~vincentp/Publications/smdae_techreport.pdf)
